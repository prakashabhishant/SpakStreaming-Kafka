# %%
import pandas as pd
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt

# %%
hotspot_terra = pd.read_csv("hotspot_TERRA_streaming.csv")

# %%
hotspot_terra.shape
# Out:
# (2623, 4)

# %%
hotspot_terra.dtypes
# Out:
# latitude                       float64
# longitude                      float64
# confidence                       int64
# surface_temperature_celcius      int64
# dtype: object

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        #value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(value))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x:dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer

# %%
#random_data = random.sample(range(0,2622),2622)

# %%
#print(random_data)

# %%
if __name__ == '__main__':
    
    sender_id = "P03"
   
    topic = 'taskc'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    while(True):
        index = random.randint(0,2622)
        my_json = hotspot_terra.loc[index].to_dict()
        my_json["sender_id"] = sender_id
        my_json["timestamp"] = str(dt.datetime.now().strftime("%X"))
        data = str(my_json)
        publish_message(producer,topic,'parsed',data)
#         sleep(random.randint(10,30))
        sleep(5)
# Out:
# Publishing records..
# Message published successfully. Data: {'longitude': 147.1609, 'confidence': 77.0, 'surface_temperature_celcius': 51.0, 'sender_id': 'P03', 'latitude': -37.8407, 'timestamp': '00:55:34'}
# Message published successfully. Data: {'longitude': 143.0869, 'confidence': 75.0, 'surface_temperature_celcius': 48.0, 'sender_id': 'P03', 'latitude': -37.4621, 'timestamp': '00:55:39'}
# Message published successfully. Data: {'longitude': 143.767, 'confidence': 77.0, 'surface_temperature_celcius': 44.0, 'sender_id': 'P03', 'latitude': -36.1, 'timestamp': '00:55:44'}
# Message published successfully. Data: {'longitude': 141.7061, 'confidence': 88.0, 'surface_temperature_celcius': 64.0, 'sender_id': 'P03', 'latitude': -36.4393, 'timestamp': '00:55:49'}
# Message published successfully. Data: {'longitude': 147.0511, 'confidence': 100.0, 'surface_temperature_celcius': 113.0, 'sender_id': 'P03', 'latitude': -37.4224, 'timestamp': '00:55:54'}
# ...
