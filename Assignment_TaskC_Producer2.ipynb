# %%
import pandas as pd
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt

# %%
hotspot_aqua = pd.read_csv("hotspot_AQUA_streaming.csv")

# %%
hotspot_aqua.shape
# Out:
# (2644, 4)

# %%
hotspot_aqua.head()
# Out:
#    latitude  longitude  confidence  surface_temperature_celcius
# 0   -37.623    149.323          51                           38
# 1   -38.038    142.986          65                           40
# 2   -37.950    142.366          92                           70
# 3   -38.231    147.172          83                           60
# 4   -37.903    145.250          53                           44

# %%
hotspot_aqua.dtypes
# Out:
# latitude                       float64
# longitude                      float64
# confidence                       int64
# surface_temperature_celcius      int64
# dtype: object

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        #value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(value))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x:dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer

# %%
#random_data = random.sample(range(0,2643),2643)

# %%
#print(random_data)

# %%
if __name__ == '__main__':
    
    sender_id = "P02"
   
    topic = 'taskc'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    
    while(True):
        index = random.randint(0,2643)
        my_json = hotspot_aqua.loc[index].to_dict()
        my_json["sender_id"] = sender_id
        my_json["timestamp"] = str(dt.datetime.now().strftime("%X"))
        data = str(my_json)
        publish_message(producer,topic,'parsed',data)
        
        sleep(random.randint(10,30))
# Out:
# Publishing records..
# Message published successfully. Data: {'longitude': 149.3911, 'surface_temperature_celcius': 41.0, 'timestamp': '23:06:53', 'latitude': -37.3252, 'sender_id': 'P02', 'confidence': 86.0}
# Message published successfully. Data: {'longitude': 141.6071, 'surface_temperature_celcius': 104.0, 'timestamp': '23:07:20', 'latitude': -36.0555, 'sender_id': 'P02', 'confidence': 100.0}
# Message published successfully. Data: {'longitude': 141.9908, 'surface_temperature_celcius': 44.0, 'timestamp': '23:07:49', 'latitude': -36.2549, 'sender_id': 'P02', 'confidence': 69.0}
# Message published successfully. Data: {'longitude': 141.3038, 'surface_temperature_celcius': 72.0, 'timestamp': '23:08:05', 'latitude': -36.663000000000004, 'sender_id': 'P02', 'confidence': 93.0}
# Message published successfully. Data: {'longitude': 143.9437, 'surface_temperature_celcius': 44.0, 'timestamp': '23:08:20', 'latitude': -36.9731, 'sender_id': 'P02', 'confidence': 69.0}
# ...
